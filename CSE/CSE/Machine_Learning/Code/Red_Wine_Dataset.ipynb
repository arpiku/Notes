# %%
import pandas as pd
df = pd.read_csv('winequalityN.csv')
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
quality_mapping = {3: 0,4: 1, 5: 2,6: 3,7: 4,8: 5}
#one can use mapping funtion in panda to map the data according to this mapping
df.loc[:,"quality"] = df['quality'].map(quality_mapping)
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8      3.0
# 1       0.49      9.5      3.0
# ...

# %%
df = df.sample(frac=1).reset_index(drop = True) #Removes the shuffled indices as a column when 'drop is true'
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.8              0.26         0.27             1.9
# 1  white            6.5              0.26         0.34             1.4
# 2  white            7.0              0.15         0.28            14.7
# 3    red            6.3              0.55         0.15             1.8
# 4  white            6.1              0.37         0.20             7.6
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.051                 52.0                 195.0  0.99280  3.23
# 1      0.040                 25.0                 184.0  0.99216  3.29
# 2      0.051                 29.0                 149.0  0.99792  2.96
# 3      0.077                 26.0                  35.0  0.99314  3.32
# 4      0.031                 49.0                 170.0  0.99558  3.22
#
#    sulphates  alcohol  quality
# 0       0.50     10.9      3.0
# 1       0.46     10.7      2.0
# ...

# %%
df_train = df.head(1000)
df_test = df.tail(599)

# %%
from sklearn import tree,metrics
from sklearn.model_selection import train_test_split

# %%
clf = tree.DecisionTreeClassifier(max_depth = 3)

cols = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']
df_train.head()
print(df_train['quality'])
# Out:
# 0      3.0
# 1      2.0
# 2      4.0
# 3      3.0
# 4      2.0
#       ...
# 995    2.0
# 996    3.0
# 997    4.0
# 998    4.0
# 999    4.0
# Name: quality, Length: 1000, dtype: float64

# %%
#Since this is not working we will do something else

#clf.fit(df_train[cols],df_train['quality'])

X  = df_train.drop(['type', 'quaility'],axis = 1)
y  = df['quality'] #braces defined the axis

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 5>()
#       1 #Since this is not working we will do something else
#       2
#       3 #clf.fit(df_train[cols],df_train['quality'])
# ----> 5 X  = df_train.drop(['type', 'quaility'],axis = 1)
#       6 y  = df['quality'] #braces defined the axis
#       8 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.7)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
